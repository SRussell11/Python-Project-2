# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 101761    False
# 101762    False
# 101763    False
# 101764    False
# 101765    False
# Length: 101766, dtype: bool

# %%
#Question: What gender was admitted via emergency room most often and received a first diagnosis for Diabetes?

# %%
drop_cols=['encounter_id','race','discharge_disposition_id', 'time_in_hospital','weight','payer_code', 'medical_specialty',
       'num_lab_procedures', 'num_procedures', 'num_medications','time_in_hospital','admission_source_id',
       'number_outpatient', 'number_emergency', 'number_inpatient','age','patient_nbr',
       'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
       'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
       'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
       'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
       'tolazamide', 'examide', 'citoglipton', 'insulin',
       'glyburide-metformin', 'glipizide-metformin',
       'glimepiride-pioglitazone', 'metformin-rosiglitazone',
       'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted']
df.drop(drop_cols,inplace=True,axis=1)

# %%
df
# Out:
#         gender  admission_type_id  diag_1
# 0       Female                  6  250.83
# 1       Female                  1     276
# 2       Female                  1     648
# 3         Male                  1       8
# 4         Male                  1     197
# ...        ...                ...     ...
# 101761    Male                  1  250.13
# 101762  Female                  1     560
# 101763    Male                  1      38
# 101764  Female                  2     996
# 101765    Male                  1     530
#
# [101766 rows x 3 columns]

# %%
df['admission_type_id']=df['admission_type_id'].replace([1],'Emergency')
df
# Out:
#         gender admission_type_id  diag_1
# 0       Female                 6  250.83
# 1       Female         Emergency     276
# 2       Female         Emergency     648
# 3         Male         Emergency       8
# 4         Male         Emergency     197
# ...        ...               ...     ...
# 101761    Male         Emergency  250.13
# 101762  Female         Emergency     560
# 101763    Male         Emergency      38
# 101764  Female                 2     996
# 101765    Male         Emergency     530
#
# [101766 rows x 3 columns]

# %%
df['admission_type_id']=df['admission_type_id'].replace([2,3],'Urgent')
df
# Out:
#         gender admission_type_id  diag_1
# 0       Female                 6  250.83
# 1       Female         Emergency     276
# 2       Female         Emergency     648
# 3         Male         Emergency       8
# 4         Male         Emergency     197
# ...        ...               ...     ...
# 101761    Male         Emergency  250.13
# 101762  Female         Emergency     560
# 101763    Male         Emergency      38
# 101764  Female            Urgent     996
# 101765    Male         Emergency     530
#
# [101766 rows x 3 columns]

# %%
df['admission_type_id']=df['admission_type_id'].replace([3],'Elective')
df
# Out:
#         gender admission_type_id  diag_1
# 0       Female                 6  250.83
# 1       Female         Emergency     276
# 2       Female         Emergency     648
# 3         Male         Emergency       8
# 4         Male         Emergency     197
# ...        ...               ...     ...
# 101761    Male         Emergency  250.13
# 101762  Female         Emergency     560
# 101763    Male         Emergency      38
# 101764  Female            Urgent     996
# 101765    Male         Emergency     530
#
# [101766 rows x 3 columns]

# %%
df['admission_type_id']=df['admission_type_id'].replace([4],'Newborn')
df
# Out:
#         gender admission_type_id  diag_1
# 0       Female                 6  250.83
# 1       Female         Emergency     276
# 2       Female         Emergency     648
# 3         Male         Emergency       8
# 4         Male         Emergency     197
# ...        ...               ...     ...
# 101761    Male         Emergency  250.13
# 101762  Female         Emergency     560
# 101763    Male         Emergency      38
# 101764  Female            Urgent     996
# 101765    Male         Emergency     530
#
# [101766 rows x 3 columns]

# %%
df['admission_type_id']=df['admission_type_id'].replace([5],'Trauma Center')
df
# Out:
#         gender admission_type_id  diag_1
# 0       Female                 6  250.83
# 1       Female         Emergency     276
# 2       Female         Emergency     648
# 3         Male         Emergency       8
# 4         Male         Emergency     197
# ...        ...               ...     ...
# 101761    Male         Emergency  250.13
# 101762  Female         Emergency     560
# 101763    Male         Emergency      38
# 101764  Female            Urgent     996
# 101765    Male         Emergency     530
#
# [101766 rows x 3 columns]

# %%
df['admission_type_id']=df['admission_type_id'].replace([9],'Information not available')
df
# Out:
#         gender admission_type_id  diag_1
# 0       Female                 6  250.83
# 1       Female         Emergency     276
# 2       Female         Emergency     648
# 3         Male         Emergency       8
# 4         Male         Emergency     197
# ...        ...               ...     ...
# 101761    Male         Emergency  250.13
# 101762  Female         Emergency     560
# 101763    Male         Emergency      38
# 101764  Female            Urgent     996
# 101765    Male         Emergency     530
#
# [101766 rows x 3 columns]

# %%
df['admission_type_id']=df['admission_type_id'].replace([6,7,8],'Reserved')
df
# Out:
#         gender admission_type_id  diag_1
# 0       Female          Reserved  250.83
# 1       Female         Emergency     276
# 2       Female         Emergency     648
# 3         Male         Emergency       8
# 4         Male         Emergency     197
# ...        ...               ...     ...
# 101761    Male         Emergency  250.13
# 101762  Female         Emergency     560
# 101763    Male         Emergency      38
# 101764  Female            Urgent     996
# 101765    Male         Emergency     530
#
# [101766 rows x 3 columns]

# %%
Emergency=df['admission_type_id']=='Emergency'

# %%
#Filter out Admission Type Id (Emergency) data
df_emergency=df[Emergency]
df_emergency
# Out:
#         gender admission_type_id  diag_1
# 1       Female         Emergency     276
# 2       Female         Emergency     648
# 3         Male         Emergency       8
# 4         Male         Emergency     197
# 7         Male         Emergency     428
# ...        ...               ...     ...
# 101760  Female         Emergency     345
# 101761    Male         Emergency  250.13
# 101762  Female         Emergency     560
# 101763    Male         Emergency      38
# 101765    Male         Emergency     530
#
# [53990 rows x 3 columns]

# %%
#Filter out Diabetes diagnosis data
Diagnosis1=df['diag_1']=250
df
# Out:
#         gender admission_type_id  diag_1
# 0       Female          Reserved     250
# 1       Female         Emergency     250
# 2       Female         Emergency     250
# 3         Male         Emergency     250
# 4         Male         Emergency     250
# ...        ...               ...     ...
# 101761    Male         Emergency     250
# 101762  Female         Emergency     250
# 101763    Male         Emergency     250
# 101764  Female            Urgent     250
# 101765    Male         Emergency     250
#
# [101766 rows x 3 columns]

# %%
#Filter out Emergency admission type by gender (Female)
Emergency_diag=df_emergency[df_emergency['gender']=='Female']
Emergency_diag
# Out:
#         gender admission_type_id diag_1
# 1       Female         Emergency    276
# 2       Female         Emergency    648
# 10      Female         Emergency  250.7
# 12      Female         Emergency    428
# 17      Female         Emergency    682
# ...        ...               ...    ...
# 101756  Female         Emergency    996
# 101757  Female         Emergency    491
# 101758  Female         Emergency    292
# 101760  Female         Emergency    345
# 101762  Female         Emergency    560
#
# [29448 rows x 3 columns]

# %%
#Calculate the total count with Emergency admission by gender
Emergency_diag_total=Emergency_diag['gender'].count()
print(Emergency_diag_total)
# Out:
# 29448

# %%
#Filter out Admission Type Id (Emergency) by Diabetes diagnosis (250)
Emergency_diag_1=Emergency_diag[Emergency_diag['diag_1']=='250']
Emergency_diag_1
# Out:
#        gender admission_type_id diag_1
# 4047     Male         Emergency    250
# 9631     Male         Emergency    250
# 10041    Male         Emergency    250
# 11801    Male         Emergency    250
# 12983    Male         Emergency    250
# ...       ...               ...    ...
# 94110    Male         Emergency    250
# 94643    Male         Emergency    250
# 96731    Male         Emergency    250
# 96897    Male         Emergency    250
# 101731   Male         Emergency    250
#
# [101 rows x 3 columns]

# %%
#Calculate the total count of Emergency admission and a diabetes diagnosis
Emergency_diag_1_total=Emergency_diag_1['diag_1'].count()
print(Emergency_diag_1_total)
# Out:
# 101

# %%
#Create new data frame for Diabetes diagnosis admitted to Emergency room by Gender 
data_for_Emergency_diag1=[['Female','Diabetes','Emergency','144'],['Male','Diabetes','Emergency','101']]
Gender_Emergency_Diag1_=pd.DataFrame(data_for_Emergency_diag1, columns=['Gender','Diag_1','Admission_type_id','Total'])
print(Gender_Emergency_Diag1_,)
# Out:
#    Gender    Diag_1 Admission_type_id Total
# 0  Female  Diabetes         Emergency   144
# 1    Male  Diabetes         Emergency   101

# %%
#Bar graph that compares the total Female vs Male that were admitted to the Emergency room and got a Diabetes diagnosis
sns.barplot(x='Gender',y='Total',data=Gender_Emergency_Diag1_)

# %%
sns.distplot(Gender_Emergency_Diag1_['Total'])
